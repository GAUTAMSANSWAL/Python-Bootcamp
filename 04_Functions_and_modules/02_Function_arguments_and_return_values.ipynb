# %% [markdown]
# Functions can take parameters and return values.

# %% [markdown]
# Types of Arguments:

# %%
# Positional Arguments

def add(a, b):
    return a + b

print(add(5, 3))   # Output:  8
# Out:
# 8
