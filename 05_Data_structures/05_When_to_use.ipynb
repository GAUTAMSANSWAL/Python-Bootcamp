# %% [markdown]
# Set : Unordered, unique
#
# for removing duplicates and set operations

# %% [markdown]
# Dictionary : Key-value pairs
#
# for fast lookups and structured data

# %% [markdown]
# list : Ordered, mutable
#
# for Storing sequences and dynamic data

# %% [markdown]
# Tuple : Ordered, immutable
#
# for fixed collections and dictionary keys
