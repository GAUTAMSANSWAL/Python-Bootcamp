# %% [markdown]
# Q1: Write a program that prints:
#
# Hello, World! Welcome to Python.

# %%
print("Hello, world! Welcome to Python.")
# Out:
# Hello, world! Welcome to Python.

# %% [markdown]
# Q2: Write a program that prints the following poem using a single print() statement:

# %%
print("johhny johhny \n yes papa \n eating sugar? \n no papa \n telling lies? \n hahaha")
# Out:
# johhny johhny
#  yes papa
#  eating sugar?
#  no papa
#  telling lies?
#  hahaha

# %% [markdown]
# Q3: Create variables to store:
#
# Your name (string)
#
# Your age (integer)
#
# Your height in meters (float)
#
# A boolean value representing whether you are a student
#
# Print all of them in one line.

# %%
name = "Gautam sanswal"
age = 21
height = 1.75
student = True

print("my name is" , name , "and i am" , age , "with a height of" , height , "meters and is student :" , student)
# Out:
# my name is Gautam sanswal and i am 21 with a height of 1.75 meters and is student : True

# %% [markdown]
# Q4: You are given a string:
#
# num = "45"
#
# Convert it into an integer
#
# Add 10 to it
#
# Print the result

# %%
num = "45"
num = int(num)
num += 10
print(num)
# Out:
# 55

# %% [markdown]
# Q5: Write a program that:
#
# Asks the user for their favorite food.
#
# Prints:
#
# Wow! I also like <food>.

# %%
food = input("what's your fav food")
print("Wow! I also like", food)
# Out:
# Wow! I also like bread

# %% [markdown]
# Q6: Write a program that:
#
# Takes two numbers as input from the user.
#
# Prints their:
#
# Sum
#
# Difference
#
# Product
#
# Quotient

# %%
a = int(input("Enter first number"))
b = int(input("Enter second number"))

print(a+b)
print(a-b)
print(a*b)
print(a/b)
# Out:
# 15
# 5
# 50
# 2.0

# %% [markdown]
# Q7: Print the following output using escape sequences:
#
# Hello "Python" World!
#
# This is on a new line.
#
# This is a tab →	    after tab.

# %%
print("Hello \"Python\" World!\nThis is on a new line.\nThis is a tab →	\tafter tab.")
# Out:
# Hello "Python" World!
# This is on a new line.
# This is a tab →		after tab.

# %% [markdown]
# Q8: Write a program that:
#
# Takes an integer as input from the user.
#
# Prints the square and cube of that number.

# %%
num = int(input("Enter the number"))
print("the square is", num**2, "\nthe cube is", num**3)
# Out:
# the square is 4
# the cube is 8
