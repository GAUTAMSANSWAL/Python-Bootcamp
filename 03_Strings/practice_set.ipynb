# %% [markdown]
# 1. Basic String Operations
#
# Create a string variable name with your full name. Print:
#
# The first character
#
# The last character
#
# The length of the string

# %%
name = "Gautam sanswal"
print("the first character is",name[0])
print("the last character is" ,name[-1])
print("the lenght of string is",len(name))
# Out:
# the first character is G
# the last character is l
# the lenght of string is 14

# %% [markdown]
# Concatenate two strings: "Hello" and "World" with a space in between.

# %%
words = ['Hello', 'World']

concatenated_string = ' '.join(words)
print(concatenated_string)
# Out:
# Hello World

# %% [markdown]
# 2. String Slicing and Indexing
#
# Given text = "Python Programming", do the following:
#
# Print the first 6 characters
#
# Print the last 6 characters
#
# Print every second character from the string
#
# Reverse the string text using slicing.

# %%
text = "Python Programming"

print("first 6 characters:", text[0:6])
print("last 6 characters:", text[-6:])
print("every second character:", text[::2])
print("reversed string is :", text[::-1])
# Out:
# first 6 characters: Python
# last 6 characters: amming
# every second character: Pto rgamn
# reversed string is : gnimmargorP nohtyP

# %% [markdown]
# 3. String Methods and Functions
#
# Take the string "  i love python programming  " and:
#
# Remove extra spaces from both ends
#
# Convert it to title case
#
# Count how many times "o" appears

# %%
string = "  i love python programming  "

new_string = string.strip().title()

print("string with removed whitespaces and title case is",new_string)

print("no of times o appears in string is",string.count('o'))
# Out:
# string with removed whitespaces and title case is I Love Python Programming
# no of times o appears in string is 3

# %% [markdown]
# Check if the string "123abc" is alphanumeric.

# %%
string = "123abc"

if string.isalnum():
    print("the string is alphanumeric")
else:
    print("the string is not alphanumeric")
# Out:
# the string is alphanumeric

# %% [markdown]
# 4. String Formatting and f-Strings
#
# Using f-strings and then format(), create a sentence:
# "My name is John and I am 25 years old."
# by passing "John" and 25 as variables.

# %%
name = "john"
age = 25

print(f"My name is {name} and I am {age} years old.")

# now doing same thing with format method

print("My name is {} and I am {} years old.".format(name, age))
# Out:
# My name is john and I am 25 years old.
# My name is john and I am 25 years old.

# %% [markdown]
# 5. String Manipulation Challenges
#
# Given sentence = "Coding in Python is fun", replace "fun" with "awesome" and print it.
#
# Find the index of the word "Python" in sentence.
#
# Convert the entire sentence to uppercase and print it.

# %%
sentence = "Coding in Python is fun"

print("after changing fun with awesome : ", sentence.replace("fun","awesome"))

print("index of word python is : ", sentence.find("Python"))

print("the string in uppercase is : ", sentence.upper())
# Out:
# after changing fun with awesome :  Coding in Python is awesome
# index of word python is :  10
# the string in uppercase is :  CODING IN PYTHON IS FUN

# %% [markdown]
# 6. Bonus Questions
#
# Write a program that counts how many vowels are in a given string.

# %%
string = input("enter a string : ")
vowels = 'aeiouAEIOU'
vowel_count = 0

for i in string:
    if i in vowels:
        vowel_count += 1
    else:
        pass

print("the number of vowels in the string is : ", vowel_count)
# Out:
# the number of vowels in the string is :  8

# %% [markdown]
# Take a user input string and check if it is a palindrome (same forwards and backwards).

# %%
string = input("enter a string : ")
if string == string[::-1]:
    print("the string is a palindrome")
else:
    print("the string is not a palindrome")
# Out:
# the string is not a palindrome
